# %%
import math
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt             
from tabulate import tabulate               
import matplotlib as mat                 
import seaborn as sns

# %% [markdown]
# ## Level 0 Tasks (Getting Started)
#
# 1.Visually inspect the first few and last few rows of the data \
# 2.Check the shape of the data frame \
# 3.Check the count of null values in each column \
# 4.Inspect all the column names and cross check with the data dictionary \
# 5.Check the information of the data frame using the info() function

# %%
# Ensure that data to be read is in the same working directory. 
df = pd.read_csv("data.csv") # read_csv: inbuilt function of pandas to read files 
df.head()   #first 5...
# Out:
#     Age Attrition     BusinessTravel              Department  \
# 0  41.0       Yes      Travel_Rarely                   Sales
# 1  49.0        No  Travel_Frequently  Research & Development
# 2  37.0       Yes      Travel_Rarely  Research & Development
# 3  33.0        No  Travel_Frequently  Research & Development
# 4  27.0        No      Travel_Rarely  Research & Development
#
#    DistanceFromHome EducationField  EmployeeNumber  EnvironmentSatisfaction  \
# 0                 1  Life Sciences               1                        2
# 1                 8  Life Sciences               2                        3
# 2                 2          Other               4                        4
# 3                 3  Life Sciences               5                        4
# 4                 2        Medical               7                        1
#
#    Gender  HourlyRate  ...  OverTime PerformanceRating  \
# 0  Female          94  ...       Yes                 3
# ...

# %%
#last 5...
df.tail()
# Out:
#        Age Attrition     BusinessTravel              Department  \
# 1465  36.0        No                NaN  Research & Development
# 1466  39.0        No      Travel_Rarely  Research & Development
# 1467  27.0        No      Travel_Rarely  Research & Development
# 1468  49.0        No  Travel_Frequently                   Sales
# 1469  34.0        No      Travel_Rarely  Research & Development
#
#       DistanceFromHome EducationField  EmployeeNumber  \
# 1465                23        Medical            2061
# 1466                 6        Medical            2062
# 1467                 4  Life Sciences            2064
# 1468                 2        Medical            2065
# 1469                 8        Medical            2068
#
#       EnvironmentSatisfaction Gender  HourlyRate  ...  OverTime  \
# 1465                        3   Male          41  ...        No
# 1466                        4   Male          42  ...        No
# ...

# %%
#rows  & columns of data (shape)...
df.shape
# Out:
# (1470, 27)

# %%
#describe or description of the data...
df.describe()
# Out:
#                Age  DistanceFromHome  EmployeeNumber  EnvironmentSatisfaction  \
# count  1446.000000       1470.000000     1470.000000              1470.000000
# mean     36.930152          9.192517     1024.865306                 2.721769
# std       9.162204          8.106864      602.024335                 1.093082
# min      18.000000          1.000000        1.000000                 1.000000
# 25%      30.000000          2.000000      491.250000                 2.000000
# 50%      36.000000          7.000000     1020.500000                 3.000000
# 75%      43.000000         14.000000     1555.750000                 4.000000
# max      60.000000         29.000000     2068.000000                 4.000000
#
#         HourlyRate  JobInvolvement  JobSatisfaction  MonthlyIncome  \
# count  1470.000000     1470.000000      1470.000000    1470.000000
# mean     65.891156        2.729932         2.728571    6502.931293
# ...

# %%
#complete picture of data i.e; info...
# returns the information about the dataset
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1470 entries, 0 to 1469
# Data columns (total 27 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Age                       1446 non-null   float64
#  1   Attrition                 1470 non-null   object
#  2   BusinessTravel            1440 non-null   object
#  3   Department                1466 non-null   object
#  4   DistanceFromHome          1470 non-null   int64
#  5   EducationField            1458 non-null   object
#  6   EmployeeNumber            1470 non-null   int64
#  7   EnvironmentSatisfaction   1470 non-null   int64
#  8   Gender                    1425 non-null   object
#  9   HourlyRate                1470 non-null   int64
#  10  JobInvolvement            1470 non-null   int64
#  11  JobRole                   1460 non-null   object
#  12  JobSatisfaction           1470 non-null   int64
# ...

# %%
#checking the null values in the data(columns) if any...
# isnull returns the True/False dataframe
#sum: counts the number of True in columns
df.isnull().sum()
# Out:
# Age                         24
# Attrition                    0
# BusinessTravel              30
# Department                   4
# DistanceFromHome             0
# EducationField              12
# EmployeeNumber               0
# EnvironmentSatisfaction      0
# Gender                      45
# HourlyRate                   0
# JobInvolvement               0
# JobRole                     10
# JobSatisfaction              0
# MaritalStatus               56
# MonthlyIncome                0
# NumCompaniesWorked           0
# Over18                      54
# OverTime                     0
# PerformanceRating            0
# RelationshipSatisfaction     0
# TotalWorkingYears            0
# TrainingTimesLastYear        0
# WorkLifeBalance              0
# YearsAtCompany               0
# YearsInCurrentRole           0
# YearsSinceLastPromotion      0
# YearsWithCurrManager         0
# dtype: int64

# %%
#returns array of columns in dataset
#extracts the column names of the data...
df.columns
# Out:
# Index(['Age', 'Attrition', 'BusinessTravel', 'Department', 'DistanceFromHome',
#        'EducationField', 'EmployeeNumber', 'EnvironmentSatisfaction', 'Gender',
#        'HourlyRate', 'JobInvolvement', 'JobRole', 'JobSatisfaction',
#        'MaritalStatus', 'MonthlyIncome', 'NumCompaniesWorked', 'Over18',
#        'OverTime', 'PerformanceRating', 'RelationshipSatisfaction',
#        'TotalWorkingYears', 'TrainingTimesLastYear', 'WorkLifeBalance',
#        'YearsAtCompany', 'YearsInCurrentRole', 'YearsSinceLastPromotion',
#        'YearsWithCurrManager'],
#       dtype='object')

# %%
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%

# %% [markdown]
# LEVEL 1 Analysis
# -------------------------
# Identify the type of data in each column (categorical or numerical)?
# 1. Seperate out the categorical columns from the numerical types
#
# ### Following are the kinds of analysis that can be performed on categorical data:
# 1. Check if the variable is  Nominal or Ordinal.
# 2. Check how many categories are present in a variable.
# 3. Check the Mode of a variable.
# 4. Check for Missing values of a variable.
# 5. Think how the missing values could be treated.
# 6. What kind of graph/chart can be plotted using this data.
#
# Note: We are analyzing only one column at a time (a.k.a. Univariate Analysis)

# %%
# Seprating out the categorical and continuous variables
def seprate_data_types(df):
    categorical = []
    continuous = []
    for column in df.columns:     # looping on the number of columns
        if df[column].nunique() < 40:     # nunique:  returns unique values in the column,
                                          #here 43 is the hyperparamter and can be changed
            categorical.append(column)
        else:
            continuous.append(column)
            
    return categorical, continuous 


categorical, continuous = seprate_data_types(df)         # Calling the function

# # Tabulate is a package used to print the list, dict or any data sets in a proper format; in table format

table = [categorical, continuous]
print(tabulate({"Categorical":categorical,
                "Continuous": continuous}, headers = ["categorical",
                                                      "continuous"]))
# Out:
# categorical               continuous
# ------------------------  -----------------
# Attrition                 Age
# BusinessTravel            EmployeeNumber
# Department                HourlyRate
# DistanceFromHome          MonthlyIncome
# EducationField            TotalWorkingYears
# EnvironmentSatisfaction
# Gender
# JobInvolvement
# JobRole
# JobSatisfaction
# MaritalStatus
# NumCompaniesWorked
# Over18
# OverTime
# PerformanceRating
# RelationshipSatisfaction
# TrainingTimesLastYear
# WorkLifeBalance
# YearsAtCompany
# YearsInCurrentRole
# YearsSinceLastPromotion
# YearsWithCurrManager

# %% [markdown]
# # $$\;\;\;\; Univariate \ Analysis \ of \ Categorical \ Variables$$
# ## Level 1 Analysis
# ### User defined functions for level 1 analysis of categorical columns
# This function will check for the following:
#
#
# - unique values
# - mode
# - sum of all the null values
# - Total count of missing values

# %%
#function for info. of categorical data...
def cat_cat_info(col):
    
    # unique: returns the unique values in the col
    print(f"Unique values in {col} are: {df[col].unique()}") 
    
    # mode: returns the mode of the column
    print(f"Mode of {col} is {df[col].mode()[0]}") 
    
    # isnull().sum() counts the number of null in dataframe
    print(f"Number of missing values in {col} is {df[col].isnull().sum()}") 
    
    # check if null values are present
    if df[col].isnull().sum() > 0:  
        
        print(f"\nThere are null values in the {col} column")

# %% [markdown]
# # 1. Analysis of Attrition:
# LEVEL 1 Analysis of Categorical Data (Univariate Analysis)

# %% [markdown]
# # Attrition

# %%
cat_cat_info("Attrition")
# Out:
# Unique values in Attrition are: ['Yes' 'No']
# Mode of Attrition is No
# Number of missing values in Attrition is 0

# %% [markdown]
# ###### Attrition Flag is a nominal data type.

# %%
def hpplots(col):

    fig, ax = plt.subplots(1, 2, figsize = (15, 7))

    # Set the title of the graph
    ax[0].set_title(col)                  

    # value_counts: returns the count of values in series: return series
    percentage = df[col].value_counts()         

    # Converting the index of value counts into list
    labels = list(df[col].value_counts().index) 


    # autopct: to print the percentage on pie wedge. 2 decimal points used
    sns.countplot(x = df[col], ax = ax[0])

    plt.pie(percentage,labels = labels, autopct= "%0.2f%%")  

    plt.show()

# %%
#Attrition...
hpplots("Attrition")

# %% [markdown]
# # Business Travel is a nominal data type.

# %%
cat_cat_info("BusinessTravel")
# Out:
# Unique values in BusinessTravel are: ['Travel_Rarely' 'Travel_Frequently' 'Non-Travel']
# Mode of BusinessTravel is Travel_Rarely
# Number of missing values in BusinessTravel is 0

# %%
#missing valuesw filled with mode()...

def fill_miss_mode(col):
    mode = df[col].mode()[0] #[0] is index, without "[0]" we'll get boolean value...
    print(mode)
    df[col].fillna(mode, inplace = True, axis = 0)

# %%
fill_miss_mode("BusinessTravel")
# Out:
# Travel_Rarely

# %%
cat_cat_info("BusinessTravel")
# Out:
# Unique values in BusinessTravel are: ['Travel_Rarely' 'Travel_Frequently' 'Non-Travel']
# Mode of BusinessTravel is Travel_Rarely
# Number of missing values in BusinessTravel is 0

# %%
#BusinessTravel...
hpplots("BusinessTravel")

# %% [markdown]
# # Department

# %%
cat_cat_info("Department")
# Out:
# Unique values in Department are: ['Sales' 'Research & Development' 'Human Resources']
# Mode of Department is Research & Development
# Number of missing values in Department is 0

# %%
#Department...
fill_miss_mode("Department")
# Out:
# Research & Development

# %%
#cross check...
cat_cat_info("Department")
# Out:
# Unique values in Department are: ['Sales' 'Research & Development' 'Human Resources']
# Mode of Department is Research & Development
# Number of missing values in Department is 0

# %%
hpplots("Department")

# %% [markdown]
# # Gender

# %%
cat_cat_info("Gender")
# Out:
# Unique values in Gender are: ['Female' 'Male' 'UnKnown']
# Mode of Gender is Male
# Number of missing values in Gender is 0

# %%
#filling missing values as unknown...
df["Gender"].fillna("UnKnown", inplace = True)

# %%
#cross check...
cat_cat_info("Gender")
# Out:
# Unique values in Gender are: ['Female' 'Male' 'UnKnown']
# Mode of Gender is Male
# Number of missing values in Gender is 0

# %%
#Gender...
hpplots("Gender")

# %% [markdown]
# # MaritalStatus

# %%
cat_cat_info("MaritalStatus")
# Out:
# Unique values in MaritalStatus are: ['Single' 'Married' 'Unknown' 'Divorced']
# Mode of MaritalStatus is Married
# Number of missing values in MaritalStatus is 0

# %%
#filling missing values as unknown...
df["MaritalStatus"].fillna("Unknown",inplace=True)

# %%
#cross check...
cat_cat_info("MaritalStatus")
# Out:
# Unique values in MaritalStatus are: ['Single' 'Married' 'Unknown' 'Divorced']
# Mode of MaritalStatus is Married
# Number of missing values in MaritalStatus is 0

# %%
#MaritalStatus...
hpplots("MaritalStatus")

# %% [markdown]
# # EducationField

# %%
cat_cat_info("EducationField")
# Out:
# Unique values in EducationField are: ['Life Sciences' 'Other' 'Medical' 'Marketing' nan 'Technical Degree'
#  'Human Resources']
# Mode of EducationField is Life Sciences
# Number of missing values in EducationField is 12
#
# There are null values in the EducationField column

# %%
#filling missing values as unknown...
df["EducationField"].fillna("Unknown",inplace=True)

# %%
cat_cat_info("EducationField")
# Out:
# Unique values in EducationField are: ['Life Sciences' 'Other' 'Medical' 'Marketing' 'Unknown'
#  'Technical Degree' 'Human Resources']
# Mode of EducationField is Life Sciences
# Number of missing values in EducationField is 0

# %%
hpplots("EducationField")

# %% [markdown]
# # Univariate Analysis of Numerical Columns...

# %%
#User defined function for extracting numerical category column info...
def numerical_cat_info(col):
    
    print(f"The mean of the {col} is {df[col].mean()}")
    
    print(f"The median of the {col} is {df[col].median()}")
    
    print(f"The mode of the {col} is {df[col].mode()[0]}")
    
    print(f"The standard deviation of the {col} is {df[col].std()}")
    
    print(f"Number of missing values in the {col} is {df[col].isnull().sum()}")

# %%
#User defined function for drawing a boxplot and a histogram...
def box_hist(col):

    fig, ax = plt.subplots(1, 2, figsize= (20, 7))

    sns.histplot(x = df[col], ax =ax[1], color = "m") 

    sns.boxplot(x = df[col], ax = ax[0], color = "g") 

    plt.show()

# %%
#filling mising values with mean in numerical data...
mean = 36
df["Age"].fillna(mean, axis = 0, inplace = True)

# %% [markdown]
# # Age

# %%
numerical_cat_info("Age")
# Out:
# The mean of the Age is 36.93015214384509
# The median of the Age is 36.0
# The mode of the Age is 34.0
# The standard deviation of the Age is 9.16220404447613
# Number of missing values in the Age is 24

# %%
#Age...
box_hist("Age")

# %%
#filling mising values with mean in numerical data...
mean=36.93015214384509
df["Age"].fillna(mean,
                axis=0,
                inplace=True)

# %%
#cross check...
numerical_cat_info("Age")
# Out:
# The mean of the Age is 36.93015214384509
# The median of the Age is 36.0
# The mode of the Age is 34.0
# The standard deviation of the Age is 9.087051409165523
# Number of missing values in the Age is 0

# %%
box_hist("Age")

# %% [markdown]
# # HourlyRate

# %%
numerical_cat_info("HourlyRate")
# Out:
# The mean of the HourlyRate is 65.89115646258503
# The median of the HourlyRate is 66.0
# The mode of the HourlyRate is 66
# The standard deviation of the HourlyRate is 20.329427593996165
# Number of missing values in the HourlyRate is 0

# %%
box_hist("HourlyRate")

# %% [markdown]
# # MonthlyIncome

# %%
numerical_cat_info("MonthlyIncome")
# Out:
# The mean of the MonthlyIncome is 6502.931292517007
# The median of the MonthlyIncome is 4919.0
# The mode of the MonthlyIncome is 2342
# The standard deviation of the MonthlyIncome is 4707.956783097994
# Number of missing values in the MonthlyIncome is 0

# %%
box_hist("MonthlyIncome")

# %%
#No outliers...
#not a human error, human behaviour change (visuals) at the end...
#higher salary employees at the end...

# %% [markdown]
# # TotalWorkingYears

# %%
numerical_cat_info("TotalWorkingYears")
# Out:
# The mean of the TotalWorkingYears is 11.279591836734694
# The median of the TotalWorkingYears is 10.0
# The mode of the TotalWorkingYears is 10
# The standard deviation of the TotalWorkingYears is 7.780781675514997
# Number of missing values in the TotalWorkingYears is 0

# %%
box_hist("TotalWorkingYears")

# %%
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%

# %% [markdown]
# Level 2 Analysis (Getting closer to the BIG QUESTION: Employee's Attrition)
# ---------------------------------------------------------------------------------------------------
#
# How can this column make way to further analysis to answer the big question?
#
# What other columns could be clubbed with Employee churn to ask further questions?
#
# The below is the variables list of columns/features in the given data.

# %% [markdown]
# # CAT-CAT ANALYSIS  (relationship between categorical data)

# %%
def cat_cat_hist(col):
    fig, ax = plt.subplots(figsize = (10, 7))
    sns.countplot(x = (col), hue = "Attrition", data = df)
    plt.show()

# %% [markdown]
# # BusinessTravel

# %%
cat_cat_hist("BusinessTravel")

# %% [markdown]
# ## Interpretation:

# %% [markdown]
# >As per the above representation, we can notice that the attrited employees are less interested in travelling trips when compared to existing employees.
#
# >Here the employees which are attrited are also a rare travellers but agein less interested in travelling when compared to existing employees.
#
# >And yes there are non-travellers too in the departments in which again the attrited employees are less interested than the existing employees.
#
# ##### Conclusion:
#
# >So, here the we can conclude that the employee ratio of less intersted travellers are more likely to quit their works or jobs compared to the

# %% [markdown]
# # EducationalField

# %%
cat_cat_hist("EducationField")

# %%
level 3: mv'
    1
    2
    3

# %% [markdown]
# ## Interpretation:

# %% [markdown]
# ##### Conclusion:
#
# >Employees from the Life Sciences & medical the attrition level of employees are a quite similar and more attriton level when compared to the other educational streams.
#
# >>In Marketing profession employee's we can also notice attrited employee's is in excess percentage...
#
# >>>As there are less no. of employees in the Resources and other streams there too are some attrited employees but in Resources Educational Field there are more attritions for overall employment of existing level at present.
#
# >>>>And Yes there are some streams that are not known...

# %% [markdown]
# # Department

# %%
cat_cat_hist("Department")

# %% [markdown]
# ##### Conclusion:
#
# >The HR department seems to have the lowest attrition in terms of numbers.

# %% [markdown]
# # CAT-NUM ANALYSIS (relationship between categorical and numerical data)

# %%
def box_hist_cn(col):  
    
    fig, ax = plt.subplots(1,                   #for creaing sublots(empty)...
                           2,
                           figsize = (15, 7))
    
    sns.histplot(x = df[col],                   #for histogram...
                 hue = df["Attrition"],
                 ax = ax[0])
    
    sns.boxplot(y = df[col],                    #for boxplot...
                x = df["Attrition"],
                ax = ax[1])
    
    plt.show()

# %% [markdown]
# # Age

# %%
box_hist_cn("Age")

# %% [markdown]
# ##### Conclusion:
#
# >Although the HR team's attrition seems to be on the lower side, the above figures do not verify the same.

# %% [markdown]
# # HourlyRate

# %%
box_hist_cn("HourlyRate")

# %% [markdown]
# # fgf

# %% [markdown]
# # TotalWorkingYears

# %%
box_hist_cn("TotalWorkingYears")

# %% [markdown]
# # fgfd

# %% [markdown]
# # LEVEL 3

# %% [markdown]
# 1.In which department there are employees which are at=trited and existing in which whom are more or less interested in travelling?
#
# 2.business travelling : in which job role are more paid and from which department are they an
# 1.
# *  correlation b/w the department and the employees who are not traveling and leave the company
# *  correlation b/w the relation between the department and the employees who are frequently travelling and not leave the country
# 2.
# *  correlation b/w the no of women who are from human resources and left the company
# *  identify the no of men who are from technical degree and left the company
# 3.
# *  correlation b/w work years of employees with sales department who are going to leave the company
# *  correlation b/w total working years of employees with sales department who are in the company
# 4.
# *  correlation b/w age group and sales department who left the company
# *  check the no of women from hr department who are in the company
# 5.
# *  correlation b/w between hourly rate of the employees who are single and left the company
# *  correlation b/w the between hourly rate of the employees who are married and left the company
# 6.
# *  correlation b/w males who have total working experience more than 25 and still in the company
# *  correlation b/w females who have total working experience more than 25 and still in the company

# %%
df.columns
# Out:
# Index(['Age', 'Attrition', 'BusinessTravel', 'Department', 'DistanceFromHome',
#        'EducationField', 'EmployeeNumber', 'EnvironmentSatisfaction', 'Gender',
#        'HourlyRate', 'JobInvolvement', 'JobRole', 'JobSatisfaction',
#        'MaritalStatus', 'MonthlyIncome', 'NumCompaniesWorked', 'Over18',
#        'OverTime', 'PerformanceRating', 'RelationshipSatisfaction',
#        'TotalWorkingYears', 'TrainingTimesLastYear', 'WorkLifeBalance',
#        'YearsAtCompany', 'YearsInCurrentRole', 'YearsSinceLastPromotion',
#        'YearsWithCurrManager'],
#       dtype='object')

# %%
#%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%

# %%
df
# Out:
#        Age Attrition     BusinessTravel              Department  \
# 0     41.0       Yes      Travel_Rarely                   Sales
# 1     49.0        No  Travel_Frequently  Research & Development
# 2     37.0       Yes      Travel_Rarely  Research & Development
# 3     33.0        No  Travel_Frequently  Research & Development
# 4     27.0        No      Travel_Rarely  Research & Development
# ...    ...       ...                ...                     ...
# 1465  36.0        No                NaN  Research & Development
# 1466  39.0        No      Travel_Rarely  Research & Development
# 1467  27.0        No      Travel_Rarely  Research & Development
# 1468  49.0        No  Travel_Frequently                   Sales
# 1469  34.0        No      Travel_Rarely  Research & Development
#
#       DistanceFromHome EducationField  EmployeeNumber  \
# 0                    1  Life Sciences               1
# 1                    8  Life Sciences               2
# ...

# %% [markdown]
# # Q1

# %%
#filter=df[(df['Attrition']=='No') & (df['BusinessTravel']=='Travel_Frequently')]

# %%
#for filtered data representation.....
#sns.countplot(x='Department',hue='Attrition',data=x1)

# %%
q1=df[(df["Attrition"]=="Yes")&(df["BusinessTravel"]=="Travel_Frequently")]
q1
# Out:
#        Age Attrition     BusinessTravel              Department  \
# 26    32.0       Yes  Travel_Frequently  Research & Development
# 102   20.0       Yes  Travel_Frequently  Research & Development
# 111   34.0       Yes  Travel_Frequently  Research & Development
# 136   51.0       Yes  Travel_Frequently  Research & Development
# 171   19.0       Yes  Travel_Frequently                   Sales
# ...    ...       ...                ...                     ...
# 1365  29.0       Yes  Travel_Frequently                   Sales
# 1375  32.0       Yes  Travel_Frequently  Research & Development
# 1379  27.0       Yes  Travel_Frequently         Human Resources
# 1395  31.0       Yes  Travel_Frequently                   Sales
# 1438  23.0       Yes  Travel_Frequently                   Sales
#
#       DistanceFromHome    EducationField  EmployeeNumber  \
# 26                  16     Life Sciences              33
# 102                  6     Life Sciences             137
# ...

# %%
sns.countplot(x='Department',hue='Attrition',data=q1)
# Out:
# <AxesSubplot:xlabel='Department', ylabel='count'>

# %% [markdown]
# # Q2

# %%
q2=df[(df["Attrition"]=="Yes")&(df["EducationField"]=="Technical Degree")]
q2
# Out:
#        Age Attrition     BusinessTravel              Department  \
# 33    39.0       Yes      Travel_Rarely                   Sales
# 45    41.0       Yes      Travel_Rarely  Research & Development
# 51    28.0       Yes      Travel_Rarely  Research & Development
# 171   19.0       Yes  Travel_Frequently                   Sales
# 214   30.0       Yes      Travel_Rarely  Research & Development
# 217   29.0       Yes      Travel_Rarely  Research & Development
# 357   21.0       Yes  Travel_Frequently                   Sales
# 385   30.0       Yes  Travel_Frequently  Research & Development
# 414   24.0       Yes      Travel_Rarely                   Sales
# 421   29.0       Yes      Travel_Rarely  Research & Development
# 422   19.0       Yes      Travel_Rarely         Human Resources
# 443   22.0       Yes  Travel_Frequently  Research & Development
# 463   26.0       Yes      Travel_Rarely  Research & Development
# 528   50.0       Yes  Travel_Frequently                   Sales
# ...

# %%
sns.countplot(x='Department',hue='Attrition',data=q2)
# Out:
# <AxesSubplot:xlabel='Department', ylabel='count'>

# %%
x1=df[(df.Attrition=='Yes') & (df.BusinessTravel=='Travel_Rarely')]
x1
# Out:
#        Age Attrition BusinessTravel              Department  DistanceFromHome  \
# 0     41.0       Yes  Travel_Rarely                   Sales                 1
# 2     37.0       Yes  Travel_Rarely  Research & Development                 2
# 14    28.0       Yes  Travel_Rarely  Research & Development                24
# 21    36.0       Yes  Travel_Rarely                   Sales                 9
# 24    34.0       Yes  Travel_Rarely  Research & Development                 6
# ...    ...       ...            ...                     ...               ...
# 1390  28.0       Yes  Travel_Rarely  Research & Development                17
# 1396  53.0       Yes  Travel_Rarely                   Sales                24
# 1442  29.0       Yes  Travel_Rarely  Research & Development                 1
# 1444  56.0       Yes  Travel_Rarely  Research & Development                 7
# 1461  50.0       Yes  Travel_Rarely                   Sales                28
#
# ...
